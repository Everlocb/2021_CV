# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
import random
from skimage import feature

# %%
image = data.camera()
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        image[i,j] += random.randint(-20,20)

# %%
plt.imshow(image, cmap = plt.cm.gray)

# %%
mm = np.median(image)
print(mm)
binary = image > mm
plt.imshow(binary, cmap = plt.cm.gray)
# Out:
# 145.0

# %%
edges = feature.canny(image,sigma=2,)
plt.imshow(edges, cmap = plt.cm.gray)

# %%
image_proc = data.camera()
edges_sharp = feature.canny(image_proc,sigma=2,)
plt.imshow(edges_sharp, cmap = plt.cm.gray)

# %%
image_proc
# Out:
# array([[156, 157, 160, ..., 152, 152, 152],
#        [156, 157, 159, ..., 152, 152, 152],
#        [158, 157, 156, ..., 152, 152, 152],
#        ...,
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111]], dtype=uint8)

# %%
edges_sharp
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
image_soft = data.camera()
edges_soft = feature.canny(image_proc,sigma=4.5,)
plt.imshow(edges_sharp, cmap = plt.cm.gray)

# %%
edges_soft
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])
